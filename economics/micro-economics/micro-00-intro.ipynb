# %% [markdown]
# # Microéconomie — Théorie du consommateur

# %% [markdown]
# # Table des matières
#
# 1. [00. Motivation](micro-01-motivation.ipynb)
# 2. [01. Préférences, paniers et axiomes](micro-02-preferences.ipynb)
# 3. [02. Fonction d'utilité et courbes d'indifférence](micro-03-utilite-indifference.ipynb)
# 4. [03. TMS, utilités marginales et formes de préférences](micro-04-tms-preferences.ipynb)
# 5. [04. Contrainte budgétaire](micro-05-contrainte-budgetaire.ipynb)
# 6. [05. Choix optimal du consommateur](micro-06-choix-optimal.ipynb)
# 7. [06. Demande individuelle et fonctions de demande](micro-07-demande-individuelle.ipynb)
# 8. [07. Élasticités](micro-08-elasticites.ipynb)
# 9. [08. Effet prix, effet revenu, effet substitution](micro-09-effets-prix-revenu-substitution.ipynb)
# 10. [09. Biens normaux, inférieurs, Giffen, luxe, nécessité](micro-10-types-de-biens.ipynb)
# 11. [10. Préférences révélées](micro-11-preferences-revelees.ipynb)
# 12. [11. Arbitrage travail-loisir](micro-12-travail-loisir.ipynb)
# 13. [12. Choix intertemporel : consommer aujourd'hui ou demain](micro-13-choix-intertemporel.ipynb)
# 14. [13. Capital humain et durée d'étude](micro-14-capital-humain.ipynb)
# 15. [14. Choix en univers risqué](micro-15-risque.ipynb)
# 16. [Annexes](micro-99-annexes.ipynb)
#
# ---

# %% [markdown]
# # Comment lire ce cours vite
#
# **Si tu manques de temps**, garde toujours le même ordre de lecture dans chaque chapitre :
#
# 1. lire l'idée générale ;
# 2. regarder le schéma support ;
# 3. retenir la formule-clé ;
# 4. finir par l'erreur classique à ne pas faire.
#
# **Pour un premier passage** : l'objectif n'est pas de tout mémoriser d'un coup. Il faut d'abord comprendre le mécanisme économique, puis fixer les formules utiles.
